# %% [markdown]
# Dataset Description:
#
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
#
# Attribute Information:
#
# All 34 are continuous
#
# The 35th attribute is either "good" or "bad" according to the definition
# summarized above. This is a binary classification task.
#
#
# WORKFLOW :
#
# Load Data
#
# Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
#
# Shuffle the data if needed.
#
# Standardized the Input Variables. Hint: Centeralized the data
#
# Split into 60 and 40 ratio.
#
# Encode labels.
#
# Model : 1 hidden layers including 16 unit.
#
# Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# Train the Model with Epochs (100).
#
# If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# Prediction should be > 92%
#
# Evaluation Step
#
# Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import tensorflow as tf


path = "/content/drive/MyDrive/Colab Notebooks/ionosphere_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
#  19  feature20  351 non-null    float64
#  20  feature21  351 non-null    float64
#  21  feature22  351 non-null    float64
#  22  feature23  351 non-null    float64
#  23  feature24  351 non-null    float64
#  24  feature25  351 non-null    float64
#  25  feature26  351 non-null    float64
#  26  feature27  351 non-null    float64
#  27  feature28  351 non-null    float64
#  28  feature29  351 non-null    float64
#  29  feature30  351 non-null    float64
#  30  feature31  351 non-null    float64
#  31  feature32  351 non-null    float64
#  32  feature33  351 non-null    float64
#  33  feature34  351 non-null    float64
#  34  label      351 non-null    object
# dtypes: float64(32), int64(2), object(1)
# memory usage: 96.1+ KB

# %%
df.isnull().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
df.describe()
# Out:
#          feature1  feature2    feature3  ...   feature32   feature33   feature34
# count  351.000000     351.0  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342  ...   -0.003794    0.349364    0.014480
# std      0.311155       0.0    0.497708  ...    0.513574    0.522663    0.468337
# min      0.000000       0.0   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000       0.0    0.871110  ...    0.000000    0.409560    0.000000
# 75%      1.000000       0.0    1.000000  ...    0.200120    0.813765    0.171660
# max      1.000000       0.0    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
df.label
# Out:
# 0      g
# 1      b
# 2      g
# 3      b
# 4      g
#       ..
# 346    g
# 347    g
# 348    g
# 349    g
# 350    g
# Name: label, Length: 351, dtype: object

# %%
encoding = {'g': 1, 'b': 0}
df.label.replace(encoding, inplace=True)

# %%
df.label
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# Name: label, Length: 351, dtype: int64

# %%
data = df.iloc[:, :-1]
targets = df.iloc[:, -1]

print(data.shape)
print(targets.shape)
# Out:
# (351, 34)
# (351,)

# %%
#from sklearn.preprocessing import LabelEncoder
  
#le = LabelEncoder()
  
#df['label']= le.fit_transform(df['label'])
#print(df["label"])

# %%
from sklearn.model_selection import train_test_split

train_data, test_data, train_targets, test_targets = train_test_split(data, targets, test_size=0.3)
train_data, validation_data, train_targets, validation_targets = train_test_split(train_data, train_targets, test_size=0.2)

# %%
## Standardizing Data

mean = np.mean(train_data)
std = np.std(train_data)

train_data -= mean
train_data /= std

validation_data -= mean
validation_data /= std

test_data -= mean
test_data /= std

# %%
from keras import models, layers

model = models.Sequential()

model.add(layers.Dense(10, input_shape=(train_data.shape[1],), activation='relu'))

model.add(layers.Dense(8, activation='relu'))

model.add(layers.Dense(6, activation='relu'))

model.add(layers.Dense(1, activation='sigmoid'))

# %%
## Compilation Step

from sklearn.metrics import classification_report

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_targets, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.3641
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3834
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3781
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3729
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3672
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3453
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3677
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3401
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3860
# Epoch 10/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3839
# Epoch 11/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3849
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3656
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3542
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3651
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3771
# Epoch 16/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3755
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3531
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3511
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3745
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3667
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3667
# Epoch 22/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3672
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3766
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3531
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3740
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3792
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3891
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3693
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3802
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3594
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3604
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3630
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3714
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3365
# Epoch 35/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3787
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3589
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3839
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3719
# Epoch 39/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3672
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3693
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3714
# Epoch 42/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3625
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3589
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3813
# Epoch 45/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3615
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3802
# Epoch 47/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3516
# Epoch 48/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3552
# Epoch 49/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3985
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3636
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3589
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3740
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3792
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3703
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3552
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3875
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3709
# Epoch 58/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3839
# Epoch 59/100
# 4/4 [==============================] - 0s 6ms/step - loss: nan - accuracy: 0.3813
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3552
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3667
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3636
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3823
# Epoch 64/100
# 4/4 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.3755
# Epoch 65/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3750
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3854
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.4125
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3698
# Epoch 69/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3912
# Epoch 70/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3901
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3677
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3719
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3693
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3974
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3740
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3552
# Epoch 77/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3589
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3636
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3886
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3740
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3672
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3537
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3771
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3755
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3766
# Epoch 86/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3896
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3589
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3672
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3880
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3761
# Epoch 91/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3745
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3625
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3834
# Epoch 94/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3839
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3584
# Epoch 96/100
# 4/4 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.3558
# Epoch 97/100
# 4/4 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3651
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3558
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3552
# Epoch 100/100
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.3698

# %%
val_predictions = model.predict(validation_data)
print(val_predictions)
# Out:
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
